-- %%
-- Create Database
CREATE DATABASE SchoolDB;

-- Use Database
USE SchoolDB;

-- Create Table+0
CREATE TABLE Students (
    StudentID INT PRIMARY KEY,
    Name VARCHAR(100),
    Age INT,
    Department VARCHAR(50)
);

-- Insert Data
INSERT INTO Students (StudentID, Name, Age, Department)
VALUES
(1, 'Mohammed', 22, 'Information Systems'),
(2, 'Abel', 21, 'Computer Science'),
(3, 'Sara', 23, 'Software Engineering');

-- View Data
SELECT * FROM Students;
-- Out:
-- Error: No connection selected.
